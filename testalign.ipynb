# %%
import landmarks
import alignment
import matplotlib.pyplot as plt

# %%
cropfaces, landmark = landmarks.retina('test1.jpg')

# %%
face = alignment.get_face_align(cropfaces[0],landmark[0],'rotate')
plt.imshow(face)

# %%
face = alignment.get_face_align(cropfaces[0],landmark[0],'affine')
plt.imshow(face)

# %%
face = alignment.get_face_align(cropfaces[0],landmark[0],'similarity')
plt.imshow(face)

# %%
face = alignment.get_face_align(cropfaces[0],landmarks[0],'affine')
plt.imshow(face)

# %%
face.shape
# Out:
# (112, 112, 3)
